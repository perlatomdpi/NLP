# %% [markdown]
# <a href="https://colab.research.google.com/github/perlatomdpi/NLP/blob/main/BERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BERTopic**
# BERTopic is a topic modeling technique that leverages transformers and c-TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions. It even supports visualizations similar to LDAvis.
#
# More info at: https://github.com/MaartenGr/BERTopic/tree/master/docs/tutorial

# %%
# !pip install bertopic

# %% [markdown]
# More depending on the transformers and language backends that you will be using. The possible installations are:

# %%
# !pip install bertopic[flair]
# !pip install bertopic[gensim]
# !pip install bertopic[spacy]
# !pip install bertopic[use]

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from bertopic import BERTopic

# %% [markdown]
# #### **Load data**
# For this example, we use the popular 20 Newsgroups dataset which contains roughly 18000 newsgroups posts on 20 topics.

# %%
from sklearn.datasets import fetch_20newsgroups
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
docs[:5]

# %% [markdown]
# # **Creating Topics**

# %%
model = BERTopic(language="english")

# %%
topics, probs = model.fit_transform(docs)  # topic generation activities

# %% [markdown]
# # **Get individual topics**

# %%
model.get_topic_freq() # get number of topics and corresponding count
# Out:
#      Topic  Count
# 0       -1   8308
# 1       43    863
# 2       16    728
# 3       44    696
# 4       33    581
# ..     ...    ...
# 138     90     11
# 137     54     11
# 142    137     10
# 143    126     10
# 144     18     10
#
# [145 rows x 2 columns]

# %%
model.get_topic(0) # show me words that constitute the topic 0
# Out:
# [('15', 0.2809088634042444),
#  ('ergonomicallycorrect', 0.0),
#  ('ergoplic', 0.0),
#  ('ergonomics', 0.0),
#  ('ergonomicallyhellish', 0.0),
#  ('ergonomic', 0.0),
#  ('ergonomically', 0.0),
#  ('ergo', 0.0),
#  ('erh0362teslanjitedu', 0.0),
#  ('ericenterprisebihharvardedu', 0.0)]

# %% [markdown]
# # **Visualize topics**

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
